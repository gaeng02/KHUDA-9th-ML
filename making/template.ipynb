# %% [markdown]
# # KHUDA x기 ML세션
# Date : 202x.xx.xx ()

# %%
# import library if you need

import pandas as pd
import numpy as np

# %%
# dataset repository path
url = "https://raw.githubusercontent.com/gaeng02/KHUDA-9th-ML/main/week/dataset.csv"

# %%
df = pd.read_csv(url)
df.head()

# %%
### answer init

# the number of task
n = 4

# no use answer[0]
answer = [0] * (n+1)

# %% [markdown]
# ## Task 1

# %%
## Input Box

ans = 0





answer[1] = ans
print(answer[1])

# %% [markdown]
# ## Task 2

# %%
## Input Box

ans = 0





answer[2] = ans
print(answer[2])

# %% [markdown]
# ## Task 3

# %%
## Input Box

ans = 0





answer[3] = ans
print(answer[3])

# %% [markdown]
# ## Task 4

# %%
## Input Box

ans = 0





answer[4] = ans
print(answer[4])

# %% [markdown]
# # 정답 확인!

# %%
print("=== 작성하신 정답 ===")
for i in range (1, (n+1)) : print("Task " + str(i) + " :: " + str(answer[i]))

# %%
### 정답 채점 코드
import hashlib

ANSWER_URL = "https://raw.githubusercontent.com/gaeng02/KHUDA-9th-ML/main/week/answer.csv"

def md5 (s) : return hashlib.md5(s.encode("utf-8")).hexdigest()

ans_df = pd.read_csv(ANSWER_URL)
gt = {int(r["task"]): str(r["answer"]).strip().lower()
      for _, r in ans_df.iterrows()}

wrong = []

for i in range(1, (n+1)) :
    user_answer = "" if answer[i] is None else md5(str(answer[i]).strip().lower())
    if (user_answer != gt.get(i, "")) : wrong.append(i)

print("탈출!" if not wrong else f"틀린번호 : {wrong}")
